# %%
import csv

def unconvert(width, height, x, y, w, h):
    xmax = int((float(x)*width) + (float(w) * width)/2.0)
    xmin = int((float(x)*width) - (float(w) * width)/2.0)
    ymax = int((float(y)*height) + (float(h) * height)/2.0)
    ymin = int((float(y)*height) - (float(h) * height)/2.0)
    return (xmin, ymin, xmax, ymax)

path_of_reading_file = "temp.csv"
output_file = "result.csv"

with open(path_of_reading_file, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        width = int(row[6])
        height = int(row[7])
        class_id = row[5]
        res = unconvert(width,height,row[1],row[2],row[3],row[4])
        
        print(str(res[0]) + ',' + str(res[1]) + ',' + str(res[2]) + ',' + str(res[3]) + ',' + class_id)
        with open(output_file, "a") as f:
            f.write(row[0] + ',' + str(res[0]) + ',' + str(res[1]) + ',' + str(res[2]) + ',' + str(res[3]) + ',' + '"' + class_id + '"\n')
            f.close()
# Out:
# 176,145,474,434,cervus_elaphus
# 588,141,652,271,cervus_elaphus
# 119,172,406,472,cervus_elaphus
# 561,144,633,280,cervus_elaphus
# 181,214,417,442,cervus_elaphus
# 359,27,425,191,cervus_elaphus
# 278,107,585,409,cervus_elaphus
# 567,100,634,294,cervus_elaphus
# 1256,925,1749,1265,canis_lupus
# 2358,793,2446,918,canis_lupus
# 1196,898,1691,1259,canis_lupus
# 2344,797,2423,926,canis_lupus
# 1387,986,1693,1291,canis_lupus
# 2331,788,2402,939,canis_lupus
# 61,395,355,628,ovis_orientalis
# 346,55,435,153,ovis_orientalis
# 125,392,362,630,ovis_orientalis
# 348,59,437,153,ovis_orientalis
# 142,393,374,631,ovis_orientalis
# 342,59,439,153,ovis_orientalis
# 184,375,427,620,ovis_orientalis
# 345,86,437,150,ovis_orientalis
# 191,376,430,619,ovis_orientalis
# 352,65,442,158,ovis_orientalis
# 288,364,429,619,ovis_orientalis
# 350,77,440,170,ovis_orientalis
# 323,316,440,528,ovis_orientalis
# 370,81,472,162,ovis_orientalis
# 1,180,169,336,ovis_orientalis
# 338,300,472,488,ovis_orientalis
# 23,181,252,342,ovis_orientalis
# 377,76,500,160,ovis_orientalis
# 425,276,516,452,ovis_orientalis
# 80,178,233,350,ovis_orientalis
# 423,96,492,183,ovis_orientalis
# 250,170,351,325,ovis_orientalis
# 484,253,698,427,ovis_orientalis
# 386,103,496,189,ovis_orientalis
# 418,240,599,365,ovis_orientalis
# 617,140,694,219,ovis_orientalis
# 266,234,446,356,ovis_orientalis
# 621,148,686,220,ovis_orientalis

# %%
import csv
import cv2
import numpy

with open("/home/wildhorse_project/camera_trap_wolf/backup/retinanet_ready_csv/ideig.csv", newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        print(row[0])
#         im = cv2.imread(("/home/dkatona/sz_zs--wolf/all_pictures/" + row[0]))
        im = cv2.imread(row[0])
        h, w, c = im.shape
        with open("/home/wildhorse_project/camera_trap_wolf/backup/retinanet_ready_csv/width.txt", "a") as f:
            f.write(str(w) + "\n")
            f.close()
        with open("/home/wildhorse_project/camera_trap_wolf/backup/retinanet_ready_csv/height.txt", "a") as f:
            f.write(str(h) + "\n")
            f.close()
#         res = unconvert(width,height,row[1],row[2],row[3],row[4])
#         print(row[0] + ',' + str(res[0]) + ',' + str(res[1]) + ',' + str(res[2]) + ',' + str(res[3]) + ',' + class_id)
# Out:
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/cervus_elaphus-94.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/cervus_elaphus-94.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/cervus_elaphus-95.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/cervus_elaphus-95.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/cervus_elaphus-96.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/cervus_elaphus-96.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/cervus_elaphus-111.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/cervus_elaphus-111.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/canis_lupus-46.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/canis_lupus-46.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/canis_lupus-47.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/canis_lupus-47.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/canis_lupus-48.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/canis_lupus-48.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-1.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-1.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-2.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-2.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-3.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-3.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-4.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-4.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-5.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-5.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-6.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-6.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-8.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-8.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-8.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-13.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-13.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-13.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-23.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-23.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-23.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-27.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-27.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-27.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-96.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-96.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-98.JPG
# /home/wildhorse_project/camera_trap_wolf/raw_pictures/part2/ovis_orientalis-98.JPG
